# %% [markdown]
# # **Machine Learning: Project Part 1**
#
# ---
#
# **Author: Damien Farrell**
#
# ---

# %%
# Imports

import os
import gc
import torch
import whisper
import whisperx
import pandas as pd
import seaborn as sns
import numpy as np
from dotenv import load_dotenv
from collections import Counter
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from transformers import pipeline as transformers_pipeline
from pyannote.audio import Pipeline as AudioPipeline
from pyannote.audio.pipelines.utils.hook import ProgressHook

sns.set_theme()
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []

# %% [markdown]
# I picked a random football podcast clips to analyse as this would have people speaking over each other which would be a difficult test for the model. Unfortunately there was no women included in this clip.
#
# In the `research` folder the Trump Harris debate is analysed.

# %%
# Environment Variables
load_dotenv()
HF_API_KEY = os.getenv("HF_API_KEY")
assert HF_API_KEY, "Please set your Hugging Face API key in the HF_API_KEY environment variable."

# Audio File Path
#AUDIO_FILE_PATH = "./audio/TrumpHarrisDebate.wav"
AUDIO_FILE_PATH = "./audio/The Overlap ON TOUR! 4.mp3"
assert AUDIO_FILE_PATH, "Please place your audio in a folder called 'audio'. Note: use backslashes if on Windows"

# %% [markdown]
# ## **Project Part 1: Audio Analysis**
#
# > 1. **Performs Speaker Diarisation Analysis**
# >    - Uses pre-built models to identify who spoke and when.
# >    - Outputs time segments for each speaker and calculates total speaking time.
# > <br><br>
# > 2. **Performs Speech to Text Analysis**
# >    - Transcribes the audio for each speaker.
# >    - Combines speaker labels with the transcript (e.g., “[Speaker 1] …”).
# > <br><br>
# > 3. **Leverage a Large Language Model**
# >    - Once the transcript is annotated, the notebook can query a large language model for analysis.
# >    - Could identify speaker names and sentiment based on transcript content.
# > <br><br>
# > 4. **Testing & Evaluation**
# >    - An audio file provided for initial testing.
# >    - The performance of each component should be documented and assessed.
# > <br><br>

# %% [markdown]
# ---
#
# ### **1. Performs Speaker Diarisation Analysis**
#
# ---
#
# Using pyannote [1][2]

# %%
# instantiate the pipeline
pipeline = AudioPipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  use_auth_token="HF_API_KEY")

# %%
# run the pipeline on an audio file
with ProgressHook() as hook:
    diarisation = pipeline(AUDIO_FILE_PATH, hook=hook)
# Out:
# segmentation         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:04
# speaker_counting     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# embeddings           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:03:42
# discrete_diarization ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
print(diarisation)
# Out:
# [ 00:00:01.448 -->  00:00:04.519] A SPEAKER_08
# [ 00:00:04.519 -->  00:00:05.920] B SPEAKER_11
# [ 00:00:05.920 -->  00:00:05.937] C SPEAKER_08
# [ 00:00:05.937 -->  00:00:16.754] D SPEAKER_11
# [ 00:00:05.954 -->  00:00:06.865] E SPEAKER_08
# [ 00:00:16.754 -->  00:00:16.872] F SPEAKER_06
# [ 00:00:16.872 -->  00:00:17.513] G SPEAKER_11
# [ 00:00:17.513 -->  00:00:22.879] H SPEAKER_06
# [ 00:00:22.879 -->  00:00:28.364] I SPEAKER_07
# [ 00:00:22.964 -->  00:00:23.402] J SPEAKER_06
# [ 00:00:26.811 -->  00:00:26.828] K SPEAKER_12
# [ 00:00:26.828 -->  00:00:26.845] L SPEAKER_06
# [ 00:00:26.845 -->  00:00:27.739] M SPEAKER_12
# [ 00:00:28.077 -->  00:00:28.195] N SPEAKER_12
# [ 00:00:28.364 -->  00:00:36.059] O SPEAKER_12
# [ 00:00:36.396 -->  00:00:38.134] P SPEAKER_12
# [ 00:00:39.923 -->  00:00:41.003] Q SPEAKER_12
# [ 00:00:41.357 -->  00:00:41.374] R SPEAKER_12
# [ 00:00:41.374 -->  00:00:42.522] S SPEAKER_05
# [ 00:00:52.697 -->  00:00:54.267] T SPEAKER_00
# [ 00:00:54.942 -->  00:00:57.051] U SPEAKER_13
# [ 00:01:01.050 -->  00:01:02.333] V SPEAKER_13
# [ 00:01:03.430 -->  00:01:05.185] W SPEAKER_13
# [ 00:01:04.814 -->  00:01:05.455] X SPEAKER_00
# [ 00:01:07.750 -->  00:01:11.597] Y SPEAKER_00
# [ 00:01:14.112 -->  00:01:15.023] Z SPEAKER_00
# [ 00:01:15.023 -->  00:01:16.356] AA SPEAKER_03
# [ 00:01:18.010 -->  00:01:22.364] AB SPEAKER_03
# [ 00:01:22.515 -->  00:01:27.240] AC SPEAKER_08
# [ 00:01:28.557 -->  00:01:40.487] AD SPEAKER_08
# [ 00:01:44.301 -->  00:01:44.959] AE SPEAKER_09
# [ 00:01:46.444 -->  00:01:49.853] AF SPEAKER_09
# [ 00:01:52.047 -->  00:01:53.177] AG SPEAKER_09
# [ 00:01:52.401 -->  00:01:53.886] AH SPEAKER_08
# [ 00:01:53.970 -->  00:01:57.582] AI SPEAKER_08
# [ 00:01:57.261 -->  00:01:58.679] AJ SPEAKER_09
# [ 00:01:58.898 -->  00:02:00.096] AK SPEAKER_09
# [ 00:02:00.096 -->  00:02:00.130] AL SPEAKER_13
# [ 00:02:04.585 -->  00:02:06.374] AM SPEAKER_09
# [ 00:02:07.487 -->  00:02:08.770] AN SPEAKER_09
# [ 00:02:09.175 -->  00:02:11.639] AO SPEAKER_09
# [ 00:02:12.972 -->  00:02:12.989] AP SPEAKER_09
# [ 00:02:12.989 -->  00:02:13.630] AQ SPEAKER_08
# [ 00:02:13.664 -->  00:02:15.132] AR SPEAKER_08
# [ 00:02:15.132 -->  00:02:15.317] AS SPEAKER_09
# [ 00:02:15.317 -->  00:02:15.334] AT SPEAKER_08
# [ 00:02:15.975 -->  00:02:16.684] AU SPEAKER_08
# [ 00:02:16.937 -->  00:02:17.967] AV SPEAKER_09
# [ 00:02:17.967 -->  00:02:18.338] AW SPEAKER_13
# [ 00:02:19.384 -->  00:02:21.173] AX SPEAKER_05
# [ 00:02:21.173 -->  00:02:21.359] AY SPEAKER_02
# [ 00:02:22.135 -->  00:02:22.202] AZ SPEAKER_07
# [ 00:02:22.439 -->  00:02:23.535] BA SPEAKER_07
# [ 00:02:24.312 -->  00:02:24.750] BB SPEAKER_07
# [ 00:02:25.560 -->  00:02:26.961] BC SPEAKER_07
# [ 00:02:26.961 -->  00:02:27.029] BD SPEAKER_05
# [ 00:02:27.450 -->  00:02:27.467] BE SPEAKER_07
# [ 00:02:27.467 -->  00:02:31.416] BF SPEAKER_08
# [ 00:02:28.665 -->  00:02:29.543] BG SPEAKER_05
# [ 00:02:32.682 -->  00:02:34.065] BH SPEAKER_08
# [ 00:02:32.884 -->  00:02:32.901] BI SPEAKER_09
# [ 00:02:32.901 -->  00:02:33.660] BJ SPEAKER_05
# [ 00:02:33.660 -->  00:02:33.745] BK SPEAKER_09
# [ 00:02:33.745 -->  00:02:33.795] BL SPEAKER_06
# [ 00:02:34.319 -->  00:02:35.584] BM SPEAKER_08
# [ 00:02:36.023 -->  00:02:40.748] BN SPEAKER_08
# [ 00:02:37.154 -->  00:02:37.407] BO SPEAKER_02
# [ 00:02:37.407 -->  00:02:37.474] BP SPEAKER_09
# [ 00:02:37.474 -->  00:02:37.508] BQ SPEAKER_05
# [ 00:02:37.508 -->  00:02:37.964] BR SPEAKER_09
# [ 00:02:37.964 -->  00:02:37.980] BS SPEAKER_02
# [ 00:02:40.073 -->  00:02:40.292] BT SPEAKER_02
# [ 00:02:40.748 -->  00:02:40.849] BU SPEAKER_02
# [ 00:02:42.503 -->  00:02:43.515] BV SPEAKER_08
# [ 00:02:44.950 -->  00:02:45.034] BW SPEAKER_05
# [ 00:02:45.034 -->  00:02:45.152] BX SPEAKER_08
# [ 00:02:45.152 -->  00:02:45.287] BY SPEAKER_05
# [ 00:02:45.287 -->  00:02:49.152] BZ SPEAKER_08
# [ 00:02:46.080 -->  00:02:46.317] CA SPEAKER_02
# [ 00:02:47.363 -->  00:02:49.827] CB SPEAKER_02
# [ 00:02:51.109 -->  00:02:52.932] CC SPEAKER_08
# [ 00:02:55.142 -->  00:02:56.121] CD SPEAKER_02
# [ 00:02:55.294 -->  00:02:55.311] CE SPEAKER_06
# [ 00:02:55.311 -->  00:02:56.222] CF SPEAKER_08
# [ 00:02:56.222 -->  00:02:56.391] CG SPEAKER_02
# [ 00:02:56.391 -->  00:02:56.999] CH SPEAKER_08
# [ 00:02:56.999 -->  00:02:58.315] CI SPEAKER_02
# [ 00:02:57.032 -->  00:02:57.302] CJ SPEAKER_08
# [ 00:03:00.255 -->  00:03:02.432] CK SPEAKER_02
# [ 00:03:05.031 -->  00:03:06.027] CL SPEAKER_02
# [ 00:03:06.769 -->  00:03:08.794] CM SPEAKER_02
# [ 00:03:09.689 -->  00:03:14.582] CN SPEAKER_02
# [ 00:03:14.954 -->  00:03:16.034] CO SPEAKER_02
# [ 00:03:15.105 -->  00:03:15.612] CP SPEAKER_08
# [ 00:03:16.034 -->  00:03:16.894] CQ SPEAKER_08
# [ 00:03:17.451 -->  00:03:17.468] CR SPEAKER_08
# [ 00:03:17.468 -->  00:03:17.535] CS SPEAKER_02
# [ 00:03:17.535 -->  00:03:17.890] CT SPEAKER_08
# [ 00:03:17.890 -->  00:03:17.974] CU SPEAKER_02
# [ 00:03:17.974 -->  00:03:18.582] CV SPEAKER_08
# [ 00:03:18.160 -->  00:03:18.599] CW SPEAKER_02
# [ 00:03:18.599 -->  00:03:18.649] CX SPEAKER_08
# [ 00:03:20.725 -->  00:03:26.715] CY SPEAKER_02
# [ 00:03:21.653 -->  00:03:21.670] CZ SPEAKER_09
# [ 00:03:28.470 -->  00:03:30.968] DA SPEAKER_09
# [ 00:03:29.297 -->  00:03:29.466] DB SPEAKER_13
# [ 00:03:29.466 -->  00:03:29.972] DC SPEAKER_04
# [ 00:03:29.972 -->  00:03:31.019] DD SPEAKER_13
# [ 00:03:30.968 -->  00:03:31.019] DE SPEAKER_04
# [ 00:03:31.019 -->  00:03:31.035] DF SPEAKER_09
# [ 00:03:31.035 -->  00:03:31.052] DG SPEAKER_13
# [ 00:03:31.052 -->  00:03:31.575] DH SPEAKER_09
# [ 00:03:31.575 -->  00:03:31.845] DI SPEAKER_04
# [ 00:03:31.845 -->  00:03:31.862] DJ SPEAKER_09
# [ 00:03:33.685 -->  00:03:33.719] DK SPEAKER_04
# [ 00:03:33.719 -->  00:03:33.735] DL SPEAKER_13
# [ 00:03:33.735 -->  00:03:34.815] DM SPEAKER_04
# [ 00:03:34.630 -->  00:03:37.650] DN SPEAKER_13
# [ 00:03:38.984 -->  00:03:44.063] DO SPEAKER_13
# [ 00:03:42.443 -->  00:03:42.494] DP SPEAKER_08
# [ 00:03:46.004 -->  00:03:47.539] DQ SPEAKER_08
# [ 00:03:48.113 -->  00:03:50.256] DR SPEAKER_13
# [ 00:03:50.391 -->  00:03:57.968] DS SPEAKER_13
# [ 00:03:57.968 -->  00:03:58.542] DT SPEAKER_12
# [ 00:03:58.542 -->  00:03:58.559] DU SPEAKER_13
# [ 00:03:59.925 -->  00:04:01.596] DV SPEAKER_12
# [ 00:04:02.001 -->  00:04:02.035] DW SPEAKER_08
# [ 00:04:05.224 -->  00:04:07.519] DX SPEAKER_08
# [ 00:04:08.819 -->  00:04:09.679] DY SPEAKER_12
# [ 00:04:10.287 -->  00:04:17.037] DZ SPEAKER_08
# [ 00:04:15.012 -->  00:04:15.619] EA SPEAKER_11
# [ 00:04:17.037 -->  00:04:25.609] EB SPEAKER_11
# [ 00:04:25.609 -->  00:04:25.913] EC SPEAKER_06
# [ 00:04:25.913 -->  00:04:26.487] ED SPEAKER_11
# [ 00:04:26.487 -->  00:04:32.393] EE SPEAKER_06
# [ 00:04:31.937 -->  00:04:37.034] EF SPEAKER_07
# [ 00:04:35.802 -->  00:04:35.835] EG SPEAKER_12
# [ 00:04:35.835 -->  00:04:35.852] EH SPEAKER_06
# [ 00:04:35.852 -->  00:04:36.713] EI SPEAKER_12
# [ 00:04:37.034 -->  00:04:37.253] EJ SPEAKER_12
# [ 00:04:37.253 -->  00:04:37.304] EK SPEAKER_07
# [ 00:04:37.304 -->  00:04:45.032] EL SPEAKER_12
# [ 00:04:45.404 -->  00:04:47.125] EM SPEAKER_12
# [ 00:04:48.441 -->  00:04:49.994] EN SPEAKER_12
# [ 00:04:50.331 -->  00:04:50.382] EO SPEAKER_12
# [ 00:04:50.382 -->  00:04:53.520] EP SPEAKER_00
# [ 00:04:53.875 -->  00:04:55.748] EQ SPEAKER_00
# [ 00:04:58.364 -->  00:05:00.372] ER SPEAKER_13
# [ 00:05:00.389 -->  00:05:00.422] ES SPEAKER_13
# [ 00:05:00.422 -->  00:05:00.929] ET SPEAKER_00
# [ 00:05:02.768 -->  00:05:06.464] EU SPEAKER_00
# [ 00:05:06.464 -->  00:05:09.653] EV SPEAKER_13
# [ 00:05:10.564 -->  00:05:14.327] EW SPEAKER_10
# [ 00:05:16.437 -->  00:05:20.655] EX SPEAKER_10
# [ 00:05:21.314 -->  00:05:23.558] EY SPEAKER_10
# [ 00:05:21.752 -->  00:05:23.187] EZ SPEAKER_05
# [ 00:05:23.558 -->  00:05:24.300] FA SPEAKER_05
# [ 00:05:24.317 -->  00:05:24.334] FB SPEAKER_05
# [ 00:05:24.992 -->  00:05:26.494] FC SPEAKER_13
# [ 00:05:28.722 -->  00:05:35.910] FD SPEAKER_13
# [ 00:05:35.910 -->  00:05:37.159] FE SPEAKER_05
# [ 00:05:37.159 -->  00:05:37.345] FF SPEAKER_13
# [ 00:05:37.345 -->  00:05:37.615] FG SPEAKER_05
# [ 00:05:43.251 -->  00:05:44.787] FH SPEAKER_02
# [ 00:05:46.474 -->  00:05:48.854] FI SPEAKER_13
# [ 00:05:51.773 -->  00:05:55.519] FJ SPEAKER_13
# [ 00:05:53.325 -->  00:06:00.700] FK SPEAKER_01
# [ 00:05:57.038 -->  00:05:58.000] FL SPEAKER_13
# [ 00:05:58.540 -->  00:05:58.995] FM SPEAKER_13
# [ 00:05:59.417 -->  00:05:59.974] FN SPEAKER_13
# [ 00:05:59.974 -->  00:06:02.961] FO SPEAKER_08
# [ 00:06:01.577 -->  00:06:11.770] FP SPEAKER_01
# [ 00:06:09.846 -->  00:06:11.871] FQ SPEAKER_13
# [ 00:06:11.871 -->  00:06:11.972] FR SPEAKER_01
# [ 00:06:13.474 -->  00:06:15.972] FS SPEAKER_01
# [ 00:06:14.571 -->  00:06:14.622] FT SPEAKER_13
# [ 00:06:14.672 -->  00:06:14.909] FU SPEAKER_13
# [ 00:06:15.010 -->  00:06:15.280] FV SPEAKER_13
# [ 00:06:16.782 -->  00:06:22.131] FW SPEAKER_01
# [ 00:06:22.266 -->  00:06:28.290] FX SPEAKER_13
# [ 00:06:28.493 -->  00:06:33.944] FY SPEAKER_13
# [ 00:06:31.092 -->  00:06:31.311] FZ SPEAKER_01
# [ 00:06:31.311 -->  00:06:31.716] GA SPEAKER_08
# [ 00:06:31.716 -->  00:06:31.750] GB SPEAKER_01
# [ 00:06:33.944 -->  00:06:33.960] GC SPEAKER_01
# [ 00:06:34.686 -->  00:06:35.125] GD SPEAKER_11
# [ 00:06:35.226 -->  00:06:35.783] GE SPEAKER_08
# [ 00:06:35.783 -->  00:06:38.972] GF SPEAKER_11
# [ 00:06:39.951 -->  00:06:39.985] GG SPEAKER_11
# [ 00:06:39.985 -->  00:06:40.474] GH SPEAKER_13
# [ 00:06:40.474 -->  00:06:40.727] GI SPEAKER_08
# [ 00:06:40.559 -->  00:06:42.027] GJ SPEAKER_13
# [ 00:06:41.976 -->  00:06:48.254] GK SPEAKER_08
# [ 00:06:42.027 -->  00:06:42.719] GL SPEAKER_01
# [ 00:06:42.719 -->  00:06:42.786] GM SPEAKER_11
# [ 00:06:42.786 -->  00:06:45.570] GN SPEAKER_01
# [ 00:06:48.254 -->  00:06:56.775] GO SPEAKER_01
# [ 00:06:57.450 -->  00:06:59.121] GP SPEAKER_01
# [ 00:07:01.095 -->  00:07:02.310] GQ SPEAKER_01
# [ 00:07:02.935 -->  00:07:02.952] GR SPEAKER_01
# [ 00:07:02.952 -->  00:07:03.019] GS SPEAKER_13
# [ 00:07:03.019 -->  00:07:03.036] GT SPEAKER_01
# [ 00:07:03.036 -->  00:07:03.492] GU SPEAKER_13
# [ 00:07:05.027 -->  00:07:05.972] GV SPEAKER_13
# [ 00:07:06.698 -->  00:07:08.622] GW SPEAKER_13
# [ 00:07:09.398 -->  00:07:12.975] GX SPEAKER_13
# [ 00:07:10.545 -->  00:07:10.984] GY SPEAKER_01
# [ 00:07:12.537 -->  00:07:15.034] GZ SPEAKER_01
# [ 00:07:15.540 -->  00:07:18.527] HA SPEAKER_01
# [ 00:07:18.696 -->  00:07:24.299] HB SPEAKER_00
# [ 00:07:24.450 -->  00:07:25.109] HC SPEAKER_00
# [ 00:07:25.767 -->  00:07:28.838] HD SPEAKER_00
# [ 00:07:30.255 -->  00:07:31.032] HE SPEAKER_05
# [ 00:07:33.057 -->  00:07:33.074] HF SPEAKER_10
# [ 00:07:33.107 -->  00:07:33.715] HG SPEAKER_10
# [ 00:07:33.715 -->  00:07:33.867] HH SPEAKER_03
# [ 00:07:33.867 -->  00:07:34.035] HI SPEAKER_10
# [ 00:07:34.035 -->  00:07:34.322] HJ SPEAKER_03
# [ 00:07:34.322 -->  00:07:34.424] HK SPEAKER_10
# [ 00:07:34.424 -->  00:07:34.542] HL SPEAKER_05
# [ 00:07:34.542 -->  00:07:35.031] HM SPEAKER_00
# [ 00:07:35.031 -->  00:07:36.094] HN SPEAKER_05
# [ 00:07:36.094 -->  00:07:36.685] HO SPEAKER_00
# [ 00:07:36.685 -->  00:07:41.039] HP SPEAKER_03
# [ 00:07:41.039 -->  00:07:43.502] HQ SPEAKER_04
# [ 00:07:44.194 -->  00:07:48.075] HR SPEAKER_04
# [ 00:07:48.177 -->  00:07:50.016] HS SPEAKER_08
# [ 00:07:50.556 -->  00:07:51.096] HT SPEAKER_08
# [ 00:07:50.607 -->  00:07:50.624] HU SPEAKER_04
# [ 00:07:50.624 -->  00:07:50.657] HV SPEAKER_13
# [ 00:07:50.657 -->  00:07:50.978] HW SPEAKER_04
# [ 00:07:50.978 -->  00:07:54.353] HX SPEAKER_13
# [ 00:07:51.096 -->  00:07:51.147] HY SPEAKER_04
# [ 00:07:57.829 -->  00:08:02.470] HZ SPEAKER_13
# [ 00:08:04.174 -->  00:08:08.967] IA SPEAKER_13
# [ 00:08:08.275 -->  00:08:08.865] IB SPEAKER_03
# [ 00:08:08.967 -->  00:08:08.984] IC SPEAKER_03
# [ 00:08:08.984 -->  00:08:10.502] ID SPEAKER_13
# [ 00:08:09.557 -->  00:08:10.334] IE SPEAKER_03
# [ 00:08:13.455 -->  00:08:16.662] IF SPEAKER_00
# [ 00:08:16.982 -->  00:08:22.939] IG SPEAKER_13
# [ 00:08:23.513 -->  00:08:25.032] IH SPEAKER_13
# [ 00:08:25.032 -->  00:08:25.268] II SPEAKER_08
# [ 00:08:25.268 -->  00:08:25.285] IJ SPEAKER_13
# [ 00:08:25.605 -->  00:08:25.656] IK SPEAKER_13
# [ 00:08:25.656 -->  00:08:26.247] IL SPEAKER_08
# [ 00:08:26.770 -->  00:08:26.787] IM SPEAKER_13
# [ 00:08:26.787 -->  00:08:30.617] IN SPEAKER_08
# [ 00:08:27.192 -->  00:08:27.900] IO SPEAKER_13
# [ 00:08:31.410 -->  00:08:31.849] IP SPEAKER_08
# [ 00:08:31.849 -->  00:08:32.085] IQ SPEAKER_05
# [ 00:08:35.663 -->  00:08:37.165] IR SPEAKER_13
# [ 00:08:37.165 -->  00:08:37.182] IS SPEAKER_05
# [ 00:08:38.970 -->  00:08:43.915] IT SPEAKER_13
# [ 00:08:44.320 -->  00:08:46.514] IU SPEAKER_05
# [ 00:08:44.556 -->  00:08:44.573] IV SPEAKER_13
# [ 00:08:44.674 -->  00:08:44.809] IW SPEAKER_13
# [ 00:08:45.855 -->  00:08:46.817] IX SPEAKER_13
# [ 00:08:46.817 -->  00:08:46.935] IY SPEAKER_05
# [ 00:08:47.627 -->  00:08:49.686] IZ SPEAKER_13
# [ 00:08:49.990 -->  00:08:52.724] JA SPEAKER_13
# [ 00:08:53.213 -->  00:08:54.276] JB SPEAKER_13
# [ 00:08:54.867 -->  00:08:56.875] JC SPEAKER_13
# [ 00:08:57.685 -->  00:08:58.073] JD SPEAKER_00
# [ 00:08:59.271 -->  00:08:59.879] JE SPEAKER_00
# [ 00:09:00.672 -->  00:09:01.752] JF SPEAKER_13
# [ 00:09:01.752 -->  00:09:01.769] JG SPEAKER_08
# [ 00:09:05.380 -->  00:09:05.684] JH SPEAKER_00
# [ 00:09:05.684 -->  00:09:05.717] JI SPEAKER_05
# [ 00:09:05.717 -->  00:09:05.785] JJ SPEAKER_00
# [ 00:09:05.785 -->  00:09:05.802] JK SPEAKER_05
# [ 00:09:05.802 -->  00:09:05.869] JL SPEAKER_00
# [ 00:09:07.962 -->  00:09:08.974] JM SPEAKER_08
# [ 00:09:08.974 -->  00:09:09.379] JN SPEAKER_03
# [ 00:09:09.379 -->  00:09:10.020] JO SPEAKER_08
# [ 00:09:10.274 -->  00:09:10.358] JP SPEAKER_05
# [ 00:09:10.392 -->  00:09:10.409] JQ SPEAKER_05
# [ 00:09:10.965 -->  00:09:11.522] JR SPEAKER_05
# [ 00:09:11.539 -->  00:09:11.607] JS SPEAKER_05
# [ 00:09:11.978 -->  00:09:12.045] JT SPEAKER_05
# [ 00:09:12.130 -->  00:09:12.147] JU SPEAKER_05
# [ 00:09:12.822 -->  00:09:15.319] JV SPEAKER_03
# [ 00:09:15.488 -->  00:09:18.390] JW SPEAKER_04
# [ 00:09:18.812 -->  00:09:21.479] JX SPEAKER_04
# [ 00:09:22.339 -->  00:09:22.744] JY SPEAKER_04
# [ 00:09:22.744 -->  00:09:22.761] JZ SPEAKER_03
# [ 00:09:22.761 -->  00:09:22.964] KA SPEAKER_04
# [ 00:09:22.964 -->  00:09:24.381] KB SPEAKER_03
# [ 00:09:24.128 -->  00:09:24.719] KC SPEAKER_04
# [ 00:09:24.381 -->  00:09:24.415] KD SPEAKER_05
# [ 00:09:24.415 -->  00:09:24.499] KE SPEAKER_03
# [ 00:09:24.499 -->  00:09:24.533] KF SPEAKER_05
# [ 00:09:24.719 -->  00:09:26.035] KG SPEAKER_05
# [ 00:09:26.085 -->  00:09:26.220] KH SPEAKER_05
# [ 00:09:26.220 -->  00:09:26.457] KI SPEAKER_04
# [ 00:09:26.457 -->  00:09:26.760] KJ SPEAKER_05
# [ 00:09:26.760 -->  00:09:27.030] KK SPEAKER_04
# [ 00:09:27.030 -->  00:09:29.798] KL SPEAKER_05

# %%
diarisation.support()

# %% [markdown]
# ---
#
# ### **2. Performs Speech to Text Analysis**
#
# ---
#
# Using Whisper [3]

# %%
model = whisper.load_model("base.en")
result = model.transcribe(AUDIO_FILE_PATH, verbose=False, fp16=False)
transcript = result["text"]
# Out:
# /home/damien/Documents/ATU/machine-learning-project-1/.venv/lib/python3.12/site-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# 100%|██████████████████████████████| 58164/58164 [00:54<00:00, 1067.86frames/s]

# %%
print(transcript)
# Out:
#  The overlap on tour is brought to you by Skybat. Even that time, Roy, when you chased down Durr's, so you didn't put a hand on him, did you? No, no, no. I didn't think it was that bad at the time. You think you're just fighting your corner, and then you look and you go, the picture looks bad, don't you? It does. I think someone were, like, edited. That's sure. No, that's where my children's laid. Well, I got right up next to him. I didn't move on that porch. You were in here on the overlap. My hand. Roy key did not chase down Andy Durr's, so it's fussed up. No, I did. I did. I did. I did. It's still photographs, look, because I like where my van is popping out of my head. You put your photo shop 20 years ago. Yeah. Look, of course it was. Ew. As you know, it was behind it. Well, I guess so. Rhea, Rhea, Rhea, Rhea, Rhea, Rhea. Roy, good to be home. Good, good, good. I'm from home. This is Dublin. I'm from Carp. Oh, sorry. Oh, it's good to be back in Ireland, yeah. Yes. Carol, what about you? It's not your first trip to Ireland. No, I've loved it. What's your side? Do you think you're in Ireland as well? Carol, I want to find out. As Roy provided, it is typically warm Irish hospitality while you've been in. Yeah, we spent the last two days in court together. I've struggled to understand the word they're saying. No, but to be fair, yesterday was absolutely brilliant. Went back to Roy's two, original football clubs, Colve and Rock Mount, and it was absolutely brilliant, a little bit emotional, and we kissed the Blarnistow. Oh, my God. Well, what years ago when you were going off for a few pranks, you were coming home? That's it. Oh, that's beautiful. Oh, that's beautiful. I'm doing this. Sacrilege is building them houses there on that hill. Oh, my brother lives over there. He does, and my sister. Oh, that's unbelievable, that. Yeah. You're ready to kiss the stone? I thought it's two people holding you. Just one for you, Gary. You're lying back. I want to submit them there. There. What are you doing? Just taking away the safety net. You idiots. Can you reach? Oh, you're kidding? Yeah. Oh, it's great. I've got the gift of the gaffu. She's not nice in the bottle. The band's doing this. Go on. Oh, I love her. Look at the tarry chinging. Mm. We can spray it with there. Oh, yeah, yeah, the scouts just kissed it. He thinks he's facing it after he's kissed it. It's a big moment in local history of this. Oh, my God. That's nice. Shot in Sweetlands. Can I get up there? Come on, try it. Hello, Gary. Hey, I'm going to do it. Hey, no. Hey, she comes. What are you going to do, right? There she is. Has anything ever fell down here? There he is. The flag cab. The flag cab. There you go. There's the flag, God. It's landed on the edge. It is. I'm going to put him every day, Gary. You should have thrown up further. Thanks, Adam. Thank you so much. Thank you. Great to see you. Good luck. Wait, is it now when we go on? Well, I'm on to my old team. It's like my school by team. Listen, whatever. We'll see what amateur levels. Then referee's put up with some abuse, don't they? I don't know how to do it. We set off at the Harlan tackle. Yeah. Yeah, yeah. And if you read the referee stuff afterwards, I'm blaming you. What? Yeah. You would have to have ref in the line been said, it's only a yellow. And if you see a Tony, you're the one. That means it's a **** right. That means it's **** right. Did you ever get sent off for a descent? How long? 10, don't know. I don't think you ever put a hand on an official in an aggressive way. Even that time, Roy, when you chased down dirt, so you didn't put a hand on him, did you? No, no, no. I didn't think it was that bad at the time. You think you're just fighting your corner, then you're looking at your go, the picture looks bad, don't you? It does. I think someone were, like, edited. That's sure. None of the swan with children's line. Well, I've been riding up next to them. I didn't move that coach. You were in here ...

# %% [markdown]
# #### **Combining Speaker Diarisation and Transcript**
#
# I need to use a github repo called Whisper X in order to merge the speaker diarisation and the transcript. [6]

# %%
device = "cpu" 
audio_file = AUDIO_FILE_PATH
batch_size = 4 # reduce if low on GPU mem
compute_type = "int8" # change to "int8" if low on GPU mem (may reduce accuracy)
audio = whisperx.load_audio(AUDIO_FILE_PATH)

# %% [markdown]
# I am probably not being efficient here and re-processing the file again with WhisperX.

# %%
# Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False) # after alignment
# Out:
# Failed to align segment (" It's still photograph, so, because I like where here,"): backtrack failed, resorting to original...
# Failed to align segment (" 2004."): no characters in this segment found in model dictionary, resorting to original...

# %%
# Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token=HF_API_KEY, device=device)
diarize_segments = diarize_model(audio)
result = whisperx.assign_word_speakers(diarize_segments, result) # segments are now assigned speaker IDs
# Out:
# /home/damien/Documents/ATU/machine-learning-project-1/.venv/lib/python3.12/site-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1823.)
#   std = sequences.std(dim=-1, correction=1)

# %%
for seg in result["segments"]:
    # if no words, skip or assign "UNKNOWN"
    if not seg.get("words"):
        seg["speaker"] = "UNKNOWN_SPEAKER"
        continue
    # gather all word-level speakers
    speakers = [word.get("speaker", "UNKNOWN_SPEAKER") for word in seg["words"]]
    # pick the most frequent speaker in this segment
    seg["speaker"] = Counter(speakers).most_common(1)[0][0]

# %%
def format_conversation(conversation_dict):
    lines = []
    for segment in conversation_dict["segments"]:
        speaker = segment.get("speaker", "UNKNOWN_SPEAKER")
        text = segment["text"].strip()
        lines.append(f"[{speaker}] {text}")
    return "\n".join(lines)

# %%
conversation = format_conversation(result)
print(conversation)
# Out:
# [SPEAKER_10] The overlap on tour is brought to you by Skybat.
# [SPEAKER_07] Even that time, Roy, when you chased down Durr's,
# [SPEAKER_07] so you didn't put a hand on him, did you?
# [SPEAKER_07] No, no, no.
# [SPEAKER_07] I didn't think it was that bad at the time.
# [SPEAKER_07] You think you're just fighting your corner,
# [SPEAKER_07] and then you look and you go,
# [SPEAKER_07] the picture looks bad, don't you?
# [SPEAKER_07] It does.
# [SPEAKER_07] I think someone were, like, edited.
# [SPEAKER_02] That's sure.
# [SPEAKER_02] No, that's where my children's laid.
# [SPEAKER_02] Well, I got right up next to him.
# [SPEAKER_02] I didn't move on that porch.
# [SPEAKER_09] You were in here on the overlap.
# [SPEAKER_09] My hand.
# [SPEAKER_09] Roy key did not chase down Andy Durr's, so it's fussed up.
# [SPEAKER_08] No, I did.
# [SPEAKER_08] I did.
# [SPEAKER_08] I did.
# [SPEAKER_08] I did.
# [SPEAKER_08] It's still photographs, look, because I like where my van is popping out of my head.
# [SPEAKER_08] You put your photo shop 20 years ago.
# [SPEAKER_08] Yeah.
# [SPEAKER_08] Look, of course it was.
# [UNKNOWN_SPEAKER] Ew.
# [SPEAKER_08] As you know, it was behind it.
# [SPEAKER_02] Well, I guess so.
# [UNKNOWN_SPEAKER] Rhea, Rhea, Rhea, Rhea, Rhea, Rhea.
# [SPEAKER_01] Roy, good to be home.
# [SPEAKER_01] Good, good, good.
# [SPEAKER_06] I'm from home.
# [SPEAKER_06] This is Dublin.
# [SPEAKER_06] I'm from Carp.
# [SPEAKER_06] Oh, sorry.
# [UNKNOWN_SPEAKER] Oh, it's good to be back in Ireland, yeah.
# [SPEAKER_06] Yes.
# [SPEAKER_06] Carol, what about you?
# [SPEAKER_06] It's not your first trip to Ireland.
# [UNKNOWN_SPEAKER] No, I've loved it.
# [SPEAKER_01] What's your side?
# [SPEAKER_01] Do you think you're in Ireland as well?
# [SPEAKER_01] Carol, I want to find out.
# [SPEAKER_00] As Roy provided, it is typically warm Irish hospitality while you've been in.
# [SPEAKER_00] Yeah, we spent the last two days in court together.
# [SPEAKER_00] I've struggled to understand the word they're saying.
# [SPEAKER_10] No, but to be fair, yesterday was absolutely brilliant.
# [SPEAKER_10] Went back to Roy's two, original football clubs, Colve and Rock Mount,
# [SPEAKER_10] and it was absolutely brilliant, a little bit emotional,
# [SPEAKER_10] and we kissed the Blarnistow.
# [SPEAKER_10] Oh, my God.
# [UNKNOWN_SPEAKER] Well, what years ago when you were going off for a few pranks,
# [SPEAKER_10] you were coming home?
# [SPEAKER_06] That's it.
# [SPEAKER_06] Oh, that's beautiful.
# [UNKNOWN_SPEAKER] Oh, that's beautiful.
# [SPEAKER_10] I'm doing this.
# [SPEAKER_10] Sacrilege is building them houses there on that hill.
# [SPEAKER_06] Oh, my brother lives over there.
# [SPEAKER_06] He does, and my sister.
# [SPEAKER_10] Oh, that's unbelievable, that.
# [SPEAKER_10] Yeah.
# [SPEAKER_10] You're ready to kiss the stone?
# [SPEAKER_10] I thought it's two people holding you.
# [SPEAKER_06] Just one for you, Gary.
# [SPEAKER_10] You're lying back.
# [SPEAKER_10] I want to submit them there.
# [SPEAKER_10] There.
# [SPEAKER_10] What are you doing?
# [SPEAKER_06] Just taking away the safety net.
# [SPEAKER_09] You idiots.
# [SPEAKER_09] Can you reach?
# [SPEAKER_09] Oh, you're kidding?
# [SPEAKER_09] Yeah.
# [SPEAKER_04] Oh, it's great.
# [SPEAKER_10] I've got the gift of the gaffu.
# [SPEAKER_04] She's not nice in the bottle.
# [SPEAKER_10] The band's doing this.
# [SPEAKER_10] Go on.
# [SPEAKER_10] Oh, I love her.
# [SPEAKER_02] Look at the tarry chinging.
# [SPEAKER_10] Mm.
# [SPEAKER_10] We can spray it with there.
# [SPEAKER_10] Oh, yeah, yeah, the scouts just kissed it.
# [SPEAKER_10] He thinks he's facing it after he's kissed it.
# [SPEAKER_10] It's a big moment in local history of this.
# [SPEAKER_10] Oh, my God.
# [SPEAKER_10] That's nice.
# [SPEAKER_11] Shot in Sweetlands.
# [SPEAKER_11] Can I get up there?
# [SPEAKER_11] Come on, try it.
# [SPEAKER_11] Hello, Gary.
# [SPEAKER_11] Hey, I'm going to do it.
# [SPEAKER_11] Hey, no.
# [SPEAKER_11] Hey, she comes.
# [SPEAKER_11] What are you going to do, right?
# [SPEAKER_11] There she is.
# [SPEAKER_11] Has anything ever fell down here?
# [SPEAKER_11] There he is.
# [SPEAKER_11] The flag cab.
# [SPEAKER_11] The flag cab.
# [SPEAKER_11] There you go.
# [SPEAKER_10] There's the flag, God.
# [UNKNOWN_SPEAKER] It's landed on the edge.
# [SPEAKER_02] It is.
# [SPEAKER_02] I'm going to put him every day, Gary.
# [SPEAKER_02] You should have thrown up further.
# [SPEAKER_06] Thanks, Adam.
# [SPEAKER_06] Thank you so much.
# [SPEAKER_02] Thank you.
# [SPEAKER_00] Great to see you.
# [UNKNOWN_SPEAKER] Good luck.
# [UNKNOWN_SPEAKER] Wait, is it now when we go on?
# [SPEAKER_00] Well, I'm on to my old team.
# [SPEAKER_06] It's like my school by team.
# [SPEAKER_06] Listen, whatever.
# [SPEAKER_06] We'll see what amateur levels.
# [SPEAKER_06] Then referee's put up with some abuse, don't they?
# [SPEAKER_06] I don't know how to do it.
# [SPEAKER_10] We set off at the Harlan tackle.
# [SPEAKER_10] Yeah.
# [SPEAKER_06] Yeah, yeah.
# [SPEAKER_06] And if you read the referee stuff afterwards, I'm blaming you.
# [SPEAKER_06] What?
# [SPEAKER_06] Yeah.
# [SPEAKER_06] You would have to have ref in the line been said,
# [SPEAKER_06] it's only a yellow.
# [SPEAKER_06] And if you see a Tony, you're the one.
# [SPEAKER_08] That means it's a **** right.
# [SPEAKER_08] That means it's **** right.
# [SPEAKER_10] Did you ever get sent off for a descent?
# [SPEAKER_08] How long?
# [SPEAKER_08] 10, don't know.
# [SPEAKER_10] I don't think you ever put a hand on an official
# [SPEAKER_10] in an aggressive way.
# [SPEAKER_10] Even that time, Roy, when you chased down dirt,
# [SPEAKER_10] so you didn't put a hand on him, did you?
# [SPEAKER_07] No, no, no.
# [SPEAKER_07] I didn't think it was that bad at the time.
# [SPEAKER_07] You think you're just fighting your corner,
# [SPEAKER_07] then you're looking at your go,
# [SPEAKER_07] the picture looks bad, don't you?
# [SPEAKER_07] It does.
# [SPEAKER_07] I think someone were, like, edited.
# [SPEAKER_07] That's sure.
# [SPEAKER_02] None of the swan with children's line.
# [SPEAKER_02] Well, I've been riding up next to them.
# [SPEAKER_09] I didn't move that coach.
# [SPEAKER_09] You were in here on the overlap.
# [SPEAKER_09] My hand.
# [SPEAKER_09] Roy Key did not chase down under there, so it's photoshopped.
# [SPEAKER_08] No, I did.
# [SPEAKER_08] I did.
# [SPEAKER_08] I did.
# [UNKNOWN_SPEAKER] It's still photograph, so, because I like where here,
# [SPEAKER_08] and my van is popping out of the head.
# [SPEAKER_08] You put your photoshopped 20 years ago.
# [SPEAKER_08] Yeah.
# [SPEAKER_08] Look, of course it was.
# [SPEAKER_08] As you know, it was behind it.
# [SPEAKER_01] It's this, the picture that you think was photoshopped.
# [SPEAKER_06] I wasn't that close to him.
# [UNKNOWN_SPEAKER] You were saying there,
# [SPEAKER_01] you were just standing up for your team and your teammate.
# [SPEAKER_01] He'd just given a penalty against us.
# [SPEAKER_06] I did think it was a penalty.
# [SPEAKER_06] I always say it.
# [SPEAKER_05] We chased him, but he kept running.
# [SPEAKER_05] It would have been OK.
# [SPEAKER_05] And he kept running, so we kept chasing him.
# [SPEAKER_05] I feel like Benny Hill.
# [SPEAKER_05] Do you remember me?
# [SPEAKER_04] He is.
# [SPEAKER_04] And I was trying to hold your other players back.
# [UNKNOWN_SPEAKER] We did a lot of trouble for that.
# [SPEAKER_06] And I did see the referee a couple of weeks later,
# [SPEAKER_06] and I did apologise to him for the other players' behaviour.
# [SPEAKER_06] You got a chance, get on.
# [SPEAKER_06] You go on lads?
# [SPEAKER_06] You can get Wembley.
# [UNKNOWN_SPEAKER] Is the lads as well as they say?
# [SPEAKER_06] Is Jenson Bob going to go?
# [SPEAKER_03] Are you in the derby?
# [SPEAKER_03] Right.
# [SPEAKER_03] What's happening?
# [SPEAKER_03] We're going to come home.
# [SPEAKER_03] We'll come home.
# [SPEAKER_03] I'll see you.
# [SPEAKER_03] You're very smart.
# [SPEAKER_03] Are you the club chairman now?
# [SPEAKER_03] No, I'm the club ambassador.
# [SPEAKER_03] I was chairman.
# [SPEAKER_03] I was a chip away then, and I know I'm club ambassador,
# [SPEAKER_03] which is great.
# [SPEAKER_03] So money went missing and Bob had to resign.
# [UNKNOWN_SPEAKER] And we were enough to drink them.
# [SPEAKER_03] So it's going to be a good season.
# [SPEAKER_03] So it's going to be a good season.
# [SPEAKER_03] Hopefully.
# [SPEAKER_03] Hopefully the playoffs, you know.
# [SPEAKER_03] Hopefully we'll make the playoffs, you know.
# [SPEAKER_06] The lads don't want to know why does this stand that name after me?
# [SPEAKER_06] I would say the greatest team has named a few months ago.
# [SPEAKER_06] They didn't make that today, Bob.
# [SPEAKER_06] It was a hard family to give you.
# [SPEAKER_06] All the fame.
# [SPEAKER_06] United did play it.
# [UNKNOWN_SPEAKER] 2004.
# [SPEAKER_07] There you go.
# [SPEAKER_10] Oh, memory corner.
# [SPEAKER_07] Oh, Jesus.
# [SPEAKER_07] Hey, they're just dead now.
# [UNKNOWN_SPEAKER] I can't bother.
# [SPEAKER_10] Where are you?
# [SPEAKER_06] Where are you?
# [SPEAKER_10] Look, Jimmy, look.
# [SPEAKER_03] And you've been waiting in there.
# [SPEAKER_03] Oh, yeah.
# [SPEAKER_03] It's in bar, babe.
# [SPEAKER_10] How many goals did you score in a season, Bob?
# [SPEAKER_03] My first show here, Gary, was probably my best year, really, you know?
# [SPEAKER_03] We got promoted and I got 16 goals.
# [SPEAKER_03] That's not bad.
# [SPEAKER_03] That's not too bad.
# [SPEAKER_03] Talk to us about the nickname.
# [SPEAKER_03] I mean, you can't see it's not obvious.
# [UNKNOWN_SPEAKER] And don't worry as you find him.
# [SPEAKER_03] Paul was great for me.
# [SPEAKER_06] You know, that experienced playing League of Ireland.
# [SPEAKER_06] Yourself, obviously.
# [SPEAKER_06] I told her that.
# [SPEAKER_06] Did you know he was good straight away?
# [SPEAKER_06] He went straight away.
# [SPEAKER_03] Well, he demanded the best from everyone.
# [SPEAKER_03] And he wouldn't ask you to do something that he wouldn't do himself.
# [SPEAKER_01] We have been taking in some of your questions.
# [SPEAKER_01] We've got some of the best of them.
# [SPEAKER_01] Whoever sent this one in, I love it.
# [SPEAKER_01] Roy, could you see yourself being friends with Gary if it wasn't for football?
# [UNKNOWN_SPEAKER] LAUGHTER
# [UNKNOWN_SPEAKER] I'm not friends with him, though.
# [SPEAKER_01] LAUGHTER
# [SPEAKER_00] Would you rather, a night out in Cork, Liverpool or Manchester?
# [SPEAKER_00] Well, it certainly wouldn't be Manchester.
# [SPEAKER_00] I've been going out for about 30 years at Liverpool, so it would have to be cool.
# [SPEAKER_10] Yeah, I'd say Cork as well.
# [SPEAKER_05] We were having a lovely lunch, but Gary was in a hurry.
# [SPEAKER_05] He had to go back for a massage.
# [UNKNOWN_SPEAKER] LAUGHTER
# [SPEAKER_06] And he booked a facial.
# [SPEAKER_06] What?
# [SPEAKER_06] He booked a facial.
# [SPEAKER_06] Obviously, he's not very good.
# [SPEAKER_06] LAUGHTER
# [SPEAKER_06] He said the spas lovely at the hotel, the spas.
# [SPEAKER_06] They're not miracle workers.
# [SPEAKER_06] They're not miracle workers.
# [SPEAKER_06] They're not miracle workers.
# [SPEAKER_00] Rock and roll stuff.
# [UNKNOWN_SPEAKER] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER
# [SPEAKER_01] What was the best prank that you saw in your playing career?
# [SPEAKER_06] Do you remember my Nikki Buck with Schmichael?
# [SPEAKER_06] Yeah.
# [SPEAKER_06] Do you want to tell him that one?
# [SPEAKER_06] No, you.
# [SPEAKER_06] LAUGHTER
# [SPEAKER_06] A teapot.
# [SPEAKER_06] Yeah, spoon.
# [SPEAKER_06] Cool.
# [SPEAKER_10] Yeah, you tell it.
# [SPEAKER_10] You tell it.
# [SPEAKER_10] You had a bit of colour to the story.
# [SPEAKER_10] You were a great fan of Peter.
# [SPEAKER_10] LAUGHTER
# [SPEAKER_04] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER
# [UNKNOWN_SPEAKER] You used to know him.
# [SPEAKER_06] LAUGHTER
# [SPEAKER_06] Nikki Buck won the dressing room in the old days before it was like 14 drinks and fruit.
# [SPEAKER_06] LAUGHTER
# [SPEAKER_04] It was a teapot.
# [SPEAKER_04] And some biscuits.
# [SPEAKER_06] So love it.
# [SPEAKER_06] Nikki Buck won the good lad.
# [SPEAKER_06] Had a hot spoon and burnt Peter on there.
# [SPEAKER_06] LAUGHTER
# [SPEAKER_01] Oh.
# [SPEAKER_01] Little Peter.
# [SPEAKER_01] It was Little Peter, yeah.
# [SPEAKER_06] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER
# [SPEAKER_10] That's why you had the red nose.
# [SPEAKER_00] LAUGHTER
# [SPEAKER_10] LAUGHTER
# [SPEAKER_00] Carrot, there must have been some from your days at Liverpool.
# [SPEAKER_00] I mean, I was involved in a Christmas party.
# [SPEAKER_00] LAUGHTER
# [SPEAKER_00] We'd have to strip it on my shoulders.
# [SPEAKER_00] LAUGHTER
# [SPEAKER_00] You say that was a prank when you got home.
# [SPEAKER_00] LAUGHTER
# [SPEAKER_00] LAUGHTER
# [SPEAKER_04] LAUGHTER
# [SPEAKER_00] I look at class as a prank.
# [SPEAKER_00] LAUGHTER
# [SPEAKER_04] LAUGHTER
# [SPEAKER_04] LAUGHTER
# [UNKNOWN_SPEAKER] LAUGHTER

# %%
word_df = pd.DataFrame(result['word_segments'])
word_df
# Out:
#           word    start      end  score     speaker
# 0          The    1.467    1.568  0.986  SPEAKER_10
# 1      overlap    1.648    1.990  0.388  SPEAKER_10
# 2           on    2.030    2.111  0.752  SPEAKER_10
# 3         tour    2.171    2.472  0.793  SPEAKER_10
# 4           is    2.533    2.593  0.846  SPEAKER_10
# ...        ...      ...      ...    ...         ...
# 1604    prank.  566.898  567.000  0.016  SPEAKER_00
# 1605  LAUGHTER  567.061  567.245  0.048  SPEAKER_00
# 1606  LAUGHTER  568.122  568.878  0.412  SPEAKER_04
# 1607  LAUGHTER  569.000  569.163  0.017  SPEAKER_04
# 1608  LAUGHTER  575.000  575.162  0.024         NaN
#
# [1609 rows x 5 columns]

# %%
# Count how many words each speaker has
segment_counts = word_df['speaker'].value_counts().sort_index()

# Remove "SPEAKER_" prefix from the index (e.g., "SPEAKER_04" -> "04")
segment_counts.index = segment_counts.index.str.replace('SPEAKER_', '')

# Plot the result
segment_counts.plot(kind='bar', figsize=(8,4), title="Number of Segments by Speaker")
plt.xlabel("Speaker")
plt.xticks(rotation=0)
plt.ylabel("Segment Count")
plt.show()

# %%
# Calculate the duration for each word
word_df['duration'] = word_df['end'] - word_df['start']
word_duration = word_df.groupby('speaker', as_index=False)['duration'].sum()
word_duration['speaker'] = word_duration['speaker'].str.replace('SPEAKER_', '')

plt.figure(figsize=(8, 4))
sns.barplot(data=word_duration, x='speaker', y='duration')
plt.title("Total Spoken Duration by Speaker")
plt.xlabel("Speaker")
plt.ylabel("Total Duration (seconds)")
plt.show()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Generate a Word Cloud for all speakers
all_text = " ".join(word_df["word"].values)
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(all_text)

# Word Cloud
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ---
#
# ### **3. Leverage a Large Language Model**
#
# ---
#
# Using Llama [4][5]

# %%
system_prompt = """
Summarise:
    Provide an overview of the topics discussed. What is the conversation of?

Identify Key Points:
    Highlight significant claims or issues raised by each speaker. Can you identify each speaker?

Analyse Rhetoric:
    Examine the tone and style.

Instruction:
Using the above steps, analyse the transcript, focusing on key insights and subject matter.
"""

# %%
model_id = "meta-llama/Llama-3.2-3B-Instruct"

pipe = transformers_pipeline(
    "text-generation",
    model=model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": conversation},
]
outputs = pipe(
    messages,
    max_new_tokens=1024,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.

# %%
llm_output = outputs[0]["generated_text"][-1]["content"]
print(llm_output)
# Out:
# **Overview of the conversation:**
# The conversation appears to be a casual gathering of friends, possibly from a football (soccer) team. They are discussing their past experiences, memories, and pranks played during their playing careers. The conversation is lighthearted, humorous, and includes some references to Irish culture and traditions.
#
# **Identify Key Points:**
# Some significant claims or issues raised by each speaker include:
#
# * Roy and the others discuss a past incident where Roy chased someone down, and there is a debate about whether it was a bad incident or not.
# * Roy and the others talk about a photo that was edited, and there is a discussion about whether it was photoshopped or not.
# * The conversation also includes discussions about the team's past experiences, pranks played, and memories of their playing careers.
# * Some speakers mention their experiences playing for the same team, including mentions of their time in the League of Ireland.
#
# **Analyse Rhetoric:**
# The tone of the conversation is lighthearted, humorous, and playful. The speakers use colloquial language, slang, and informal expressions, which suggests a close-knit and familiar group of friends. The conversation is peppered with laughter, teasing, and joking, which creates a relaxed and convivial atmosphere.
#
# The style of the conversation is informal and conversational, with speakers often interrupting each other or responding to each other's comments in a spontaneous and unstructured way. This creates a sense of spontaneity and informality, which is typical of casual conversations among friends.
#
# Overall, the conversation is a relaxed and enjoyable exchange of stories, memories, and jokes among friends, which suggests a strong sense of camaraderie and shared experience.

# %% [markdown]
# ### **Sentiment Analysis**
#
# Using RoBERTa [7]

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
data = []
# Loop through each segment(sentence) and extract text and speaker
for segment in result['segments']:
    text = segment['text']
    speaker = segment['speaker']
    data.append({"Text": text, "Speaker": speaker})

sentence_df = pd.DataFrame(data)
sentence_df = sentence_df.reset_index().rename(columns={'index': 'id'})
print(sentence_df)
# Out:
#       id                                               Text          Speaker
# 0      0   The overlap on tour is brought to you by Skybat.       SPEAKER_10
# 1      1   Even that time, Roy, when you chased down Dur...       SPEAKER_07
# 2      2          so you didn't put a hand on him, did you?       SPEAKER_07
# 3      3                                        No, no, no.       SPEAKER_07
# 4      4        I didn't think it was that bad at the time.       SPEAKER_07
# ..   ...                                                ...              ...
# 307  307                        I look at class as a prank.       SPEAKER_00
# 308  308                                           LAUGHTER       SPEAKER_00
# 309  309                                           LAUGHTER       SPEAKER_04
# 310  310                                           LAUGHTER       SPEAKER_04
# 311  311                                           LAUGHTER  UNKNOWN_SPEAKER
#
# [312 rows x 3 columns]

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(sentence_df.iterrows(), total=len(sentence_df)):
    try:
        # Use index directly instead of accessing the 'Id' column
        myid = row.name  # DataFrame index
        text = row['Text']
        roberta_result = polarity_scores_roberta(text)
        res[myid] = roberta_result
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/312 [00:00<?, ?it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'id'})
results_df = results_df.merge(sentence_df, how='left')

# %%
plt.figure(figsize=(12, 6))
sns.histplot(results_df[['roberta_neg', 'roberta_neu', 'roberta_pos']], kde=True, multiple="stack")
plt.title("Distribution of Sentiment Scores")
plt.xlabel("Sentiment Score")
plt.ylabel("Frequency")
plt.legend(['Negative', 'Neutral', 'Positive'])
plt.show()

# %%
# 2. Boxplot of sentiment scores grouped by speaker
plt.figure(figsize=(12, 6))
sns.boxplot(data=results_df.melt(id_vars=['Speaker'], value_vars=['roberta_neg', 'roberta_neu', 'roberta_pos']),
            x='variable', y='value', hue='Speaker')
plt.title("Boxplot of Sentiment Scores by Speaker")
plt.xlabel("Sentiment Type")
plt.ylabel("Score")
plt.legend(title="Speaker")
plt.show()

# %%
# Grouping by Speaker and calculating mean sentiment scores
speaker_sentiment_summary = results_df.groupby('Speaker')[['roberta_neg', 'roberta_neu', 'roberta_pos']].mean()

# Remove "SPEAKER_" prefix from the index
speaker_sentiment_summary = speaker_sentiment_summary.rename(index=lambda x: x.replace('SPEAKER_', ''))

speaker_sentiment_summary.plot(kind='bar', figsize=(10, 5))
plt.title("Average Sentiment Scores by Speaker")
plt.xlabel("Speaker")
plt.ylabel("Average Sentiment Score")
plt.legend(["Negative", "Neutral", "Positive"], title="Sentiment Type")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Most positive and negative statements
most_positive = results_df.loc[results_df["roberta_pos"].idxmax()]
most_negative = results_df.loc[results_df["roberta_neg"].idxmax()]

# %%
most_positive
# Out:
# id                             108
# roberta_neg               0.002141
# roberta_neu               0.016819
# roberta_pos                0.98104
# Text            Thank you so much.
# Speaker                 SPEAKER_06
# Name: 108, dtype: object

# %%
most_negative
# Out:
# id                                         76
# roberta_neg                          0.947118
# roberta_neu                          0.049192
# roberta_pos                           0.00369
# Text            She's not nice in the bottle.
# Speaker                            SPEAKER_04
# Name: 76, dtype: object

# %% [markdown]
# ---
#
# ### **4. Testing & Evaluation**
#
# ---

# %%
avg_scores = word_df.groupby('speaker')['score'].mean()
avg_scores
# Out:
# speaker
# SPEAKER_00    0.381605
# SPEAKER_01    0.531036
# SPEAKER_02    0.347945
# SPEAKER_03    0.397071
# SPEAKER_04    0.300630
# SPEAKER_05    0.317244
# SPEAKER_06    0.377034
# SPEAKER_07    0.348750
# SPEAKER_08    0.441568
# SPEAKER_09    0.522771
# SPEAKER_10    0.415264
# SPEAKER_11    0.448625
# Name: score, dtype: float64

# %%
# Create two second time bins
word_df['time_bin'] = np.floor(word_df['start'] / 2) * 2

binned_scores = word_df.pivot_table(
    index='time_bin', columns='speaker', values='score', aggfunc='mean'
)

# Plotting the average scores over time per speaker
plt.figure(figsize=(20, 6))
for speaker in binned_scores.columns:
    plt.plot(binned_scores.index, binned_scores[speaker], marker='o', label=f'Speaker: {speaker}')

plt.xlabel('Time (s)')
plt.ylabel('Average Score')
plt.title('Average Scores Over Time Per Speaker (Two Second Bins)')
plt.legend(title='Speakers')
plt.grid()
plt.show()

# %% [markdown]
# ### **Conclusion**
#
# - The file did a pretty ok job at speaker diarisation and transcription. The scoring is not very high due to overlapping speakers in the audio file as shown in the scores above.
#
# - The LLM summarised the file well enough. It deciphered that it was friends speaking about football. It correctly determined the tone.
#
# - The sentiment analysis showed that the audio was skewed to neutral with speaker 7, Gary Neville, being the most negative.

# %% [markdown]
# ---
#
# ### **References**
#
# 1. Hugging Face (n.d.). *pyannote/segmentation*. Available at: [https://huggingface.co/pyannote/segmentation](https://huggingface.co/pyannote/segmentation) (Accessed: 13 January 2025).
# 2. pyannote (n.d.). *pyannote-core reference*. Available at: [http://pyannote.github.io/pyannote-core/reference.html#annotation](http://pyannote.github.io/pyannote-core/reference.html#annotation) (Accessed: 20 December 2024).
# 3. OpenAI (n.d.). *Whisper*. Available at: [https://github.com/openai/whisper](https://github.com/openai/whisper) (Accessed: 20 December 2024).
# 4. Meta (n.d.). *llama-models*. Available at: [https://github.com/meta-llama/llama-models](https://github.com/meta-llama/llama-models) (Accessed: 20 December 2024).
# 5. Meta (n.d.). *Llama-3.2-3B-Instruct*. Available at: [https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct](https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct) (Accessed: 20 December 2024).
# 6. Bain, M. (n.d.). *whisperX*. Available at: [https://github.com/m-bain/whisperX](https://github.com/m-bain/whisperX) (Accessed: 21 December 2024).
# 7. Mulla, R. (n.d.) Python Sentiment Analysis Project with NLTK and Transformers. Classify Amazon Reviews!!. Available at: https://www.youtube.com/watch?v=QpzMWQvxXWk (Accessed: 20 December 2024).

# %% [markdown]
# ---
#
# # END
